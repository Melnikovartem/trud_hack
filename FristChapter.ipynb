# %%
import pickle
import coras
import pymorphy2
import string
import ParsFromVK

def get_normal_form(word, morth=pymorphy2.MorphAnalyzer()): # Нормальная форма слова
    
    return morth.parse(word)[0].normal_form


def delete_punctuation(word): # Удаление всех знаков пунктуации
    
    tt = str.maketrans(dict.fromkeys(string.punctuation))
    
    return word.translate(tt)

file_1 = open('data1', 'rb')
vertex_edges = pickle.load(file_1)
professions = {'Агроном', 'Бухгалтер', 'Грузчик', 'Менеджер', 'Облицовщик', 'Пожарный', 'Учитель'}


Tree = []
Tree.append(coras.node())
Tree[0].prevNode = 0

print(vertex_edges)

cnt = {}
a = set()

for key in vertex_edges:
    if key in professions:
        cnt[key] = 0
        for j in vertex_edges[key]:
            cnt[key] += j[1]
    else:
        a.add(key)

numb = []
        
for word in a:
    coras.add_string(word, len(numb))
    numb.append(word)
            
def get_profession(cur_id):
    main_information, groups = ParsFromVK.pars_from_vk(cur_id)
    score = {}
    for prof in professions:
        score[prof] = 0
    s = ''
    for group in groups:
        words = group.split()
        for word in words:
            word = delete_punctuation(word)
            word = get_normal_form(word)
            s += word
    number_occurrences = coras.find_entry(s)
    for key in number_occurrences:
        curOccur = numb[key]
        curCnt = number_occurrences[key]
        for j in vertex_edges[curOccur]:
            if j[0] in professions:
                score[j[0]] += (j[1] / cnt[j[0]])
    s = ''
    for key in main_information:
        words = str(main_information[key]).split()
        for word in words:
            word = delete_punctuation(word)
            word = get_normal_form(word)
            s += word
    number_occurrences = coras.find_entry(s)
    for key in number_occurrences:
        curOccur = numb[key]
        curCnt = number_occurrences[key]
        for j in vertex_edges[curOccur]:
            if j[0] in professions:
                score[j[0]] += (j[1] / cnt[j[0]])
    maxVal = 0
    ans = ''
    for key in score:
        if score[key] > maxVal:
            maxVal = score[key]
            ans = key
    return ans

cur_id = 'rokolgan'
print(get_profession(cur_id))
# Out:
# {'Агроном': [('музыка', 432), ('хороший', 339), ('фильм', 308), ('новинка', 283), ('подслушать', 257), ('юмор', 227), ('рецепт', 223), ('женский', 223), ('весь', 217), ('прикол', 215), ('кино', 208), ('идея', 197), ('беларусь', 195), ('авто', 187), ('мой', 182), ('жизнь', 171), ('психология', 165), ('журнал', 164), ('факультет', 163), ('барахолка', 161), ('новость', 161), ('факт', 161), ('мир', 157), ('дом', 152), ('анекдот', 149), ('дизайн', 142), ('мужской', 140), ('типичный', 129), ('клуб', 129), ('мысль', 127), ('интересный', 124), ('футбол', 122), ('мама', 117), ('быть', 115), ('красота', 113), ('любить', 110), ('наука', 109), ('киномания', 108), ('спорт', 107), ('дача', 102), ('девушка', 99), ('ремонт', 99), ('академия', 95), ('хитрость', 88), ('сериал', 87), ('человек', 81), ('кулинария', 81), ('бизнес', 77), ('русский', 77), ('объявление', 77), ('ребёнок', 77), ('книга', 77), ('секрет', 74), ('россия', 73), ('сарказм', 71), ('рука', 70), ('любовь', 70), ('великое', 69), ('онлайн', 69), ('школа', 69), ('шедевр', 68), ('порядочный', 68), ('чёткий', 68), ('умный', 67), ('продажа', 67), ('парный', 67), ('маникюр', 66), ('самый', 65), ('агрономический', 65), ('москва', 64), ('июль', 63), ('сам', 63), ('корпорация', 63), ('история', 62), ('им