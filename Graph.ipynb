# %%
import ParsFromVK

#менеджеры
arr1 = ['id351628859', 'mongan0', 'l.skorokhod86', 'id466883526', 'sizovaarina', 'tanya.nusy', 'hummer_x007xx777', 'sefoline', 'tanya_concert', 'l.skorokhod86', 'id86902200', 'katuxa8573', 'roman31011982', 'fatalarage', 'gelashvilis']
#строители
arr2 = ['id_micha_1995', 'nataschaaa', 'a.shidiev_13', 'id151003806', 'stroitel_43', 'k.madin', 'dossina123', 'zbudyakov', 'proshko1980', 'id134685989', 'vkotyuzhinsky65', 'id177949356', '53kafel', 'id147592851', 'id31618685']
a, b, c = ParsFromVK.pars_from_vk('id_micha_1995')
cnt1 = {}
#for id in arr1:
 #   a, b, c = ParsFromVK.pars_from_vk(id)

a, b, c = ParsFromVK.pars_from_vk('nataschaaa')
for key in a:
    print(key, a[key])
print(b)
print(c)
# Out:
# id 1463483
# first_name Natasha
# last_name Vasilkova
# is_closed False
# can_access_closed True
# bdate 14.2.1993
# city {'id': 635, 'title': 'Hamburg'}
# ...
